# %% [markdown]
# # Introduction about Healthcare Dataset

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![medical.jpg](attachment:medical.jpg)

# %% [markdown]
# - The dataset contains 110,527 rows and 14 columns.
# - The key columns include:
# - PatientId and AppointmentID (Unique Identifiers)
# - Gender (Categorical: 'M' or 'F')
# - ScheduledDay and AppointmentDay (Datetime)
# - Age (Numerical)
# - Neighbourhood (Location)
# - Scholarship, Hipertension, Diabetes, Alcoholism, Handcap, SMS_received (Binary)
# - No-show (Target Variable: 'Yes' or 'No')

# %% [markdown]
# #  Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime
print("✅ libraries imported succesfully")
# Out:
# ✅ libraries imported succesfully

# %% [markdown]
# # Reading Data

# %%
# reading the dataset
df=pd.read_csv("C:\\Users\\ADMIN\\Downloads\\Data.csv")
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
# random 3 rows
df.sample(3)
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 13800   6.962483e+10        5680128      M  2016-05-10T11:08:33Z
# 108676  9.326398e+12        5756713      M  2016-06-01T08:36:21Z
# 80826   4.612326e+12        5590988      F  2016-04-15T15:33:48Z
#
#               AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 13800   2016-05-12T00:00:00Z   47        BONFIM            0             1
# 108676  2016-06-01T00:00:00Z   28        JABOUR            0             0
# 80826   2016-05-18T00:00:00Z   63       ITARARÉ            0             1
#
#         Diabetes  Alcoholism  Handcap  SMS_received No-show
# 13800          0           0        0             0      No
# 108676         0           0        0             0      No
# 80826          0           0        0             0      No

# %%
# detailed information of each column - dtype,non null values etc.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
# descriptive statistics of numeric columns
df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# rows and columns size
df.shape
# Out:
# (110527, 14)

# %% [markdown]
# # Processing Data

# %%
# checking data types of each column
df.dtypes
# Out:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship         int64
# Hipertension        int64
# Diabetes            int64
# Alcoholism          int64
# Handcap             int64
# SMS_received        int64
# No-show            object
# dtype: object

# %%
# converting the date and time into standard form
df["ScheduledDay"] = pd.to_datetime(df["ScheduledDay"]).dt.date.astype("datetime64[ns]")
df["AppointmentDay"] = pd.to_datetime(df["AppointmentDay"]).dt.date.astype("datetime64[ns]")

# %%
# return top 5 rows
df.head()
# Out:
#       PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0  2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1  5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2  4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3  8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4  8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received No-show
# 0        0             0      No
# 1        0             0      No
# ...

# %% [markdown]
# ### for the schedule day and appointment day storing the weekdays into a variable

# %%
df["sch_weekday"]=df["ScheduledDay"].dt.dayofweek
df["app_weekday"]=df["AppointmentDay"].dt.dayofweek

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0  2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1  5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2  4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3  8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4  8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received No-show  sch_weekday  app_weekday
# ...

# %% [markdown]
# ### unique values for categorical columns

# %%
df["Gender"].value_counts()
# Out:
# Gender
# F    71840
# M    38687
# Name: count, dtype: int64

# %%
df["No-show"].value_counts()
# Out:
# No-show
# No     88208
# Yes    22319
# Name: count, dtype: int64

# %% [markdown]
# #### dropping some columns which have no significance

# %%
df.drop(["PatientId","AppointmentID","Neighbourhood"],axis=1,inplace=True)

# %% [markdown]
# ### Identify numerical columns

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
numerical_columns
# Out:
# Index(['Age', 'Scholarship', 'Hipertension', 'Diabetes', 'Alcoholism',
#        'Handcap', 'SMS_received'],
#       dtype='object')

# %% [markdown]
#  ### Identify outliers using IQR method

# %%
outliers = {}
for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers[col] = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]

# %% [markdown]
# ### Print outlier counts for each numerical column

# %%
for col, outlier_values in outliers.items():
    print(f"{col} has {outlier_values.count()} outliers.")
# Out:
# Age has 5 outliers.
# Scholarship has 10861 outliers.
# Hipertension has 21801 outliers.
# Diabetes has 7943 outliers.
# Alcoholism has 3360 outliers.
# Handcap has 2241 outliers.
# SMS_received has 0 outliers.

# %% [markdown]
# ### Visualize outliers using box plots

# %%
len(numerical_columns)
# Out:
# 7

# %%
plt.figure(figsize=(12, 6))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(2, len(numerical_columns)//2 + 1, i)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Plot histograms for each numerical column

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(3, 3, i)
    df[col].hist(bins=30, edgecolor='black')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### .value_counts() counts the occurrences of each unique value

# %%
# 0 for monday ,1 for tuesday
df["sch_weekday"].value_counts()
# Out:
# sch_weekday
# 1    26168
# 2    24262
# 0    23085
# 4    18915
# 3    18073
# 5       24
# Name: count, dtype: int64

# %%
df["app_weekday"].value_counts()
# Out:
# app_weekday
# 2    25867
# 1    25640
# 0    22715
# 4    19019
# 3    17247
# 5       39
# Name: count, dtype: int64

# %% [markdown]
# #### Insights
# - Appointments scheduled on weekends (Friday, Saturday) have lower no-show rates.
# - Tuesdays and Wednesdays show slightly higher no-show rates.

# %% [markdown]
# #### checking columns names

# %%
df.columns
# Out:
# Index(['Gender', 'ScheduledDay', 'AppointmentDay', 'Age', 'Scholarship',
#        'Hipertension', 'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received',
#        'No-show', 'sch_weekday', 'app_weekday'],
#       dtype='object')

# %% [markdown]
# #### changing the name of some columns

# %%
df=df.rename(columns={"Hipertension": "Hypertension","Handcap":"Handicap","SMS_received":"SMSReceived","No-show":"NoShow"})

# %%
df.columns
# Out:
# Index(['Gender', 'ScheduledDay', 'AppointmentDay', 'Age', 'Scholarship',
#        'Hypertension', 'Diabetes', 'Alcoholism', 'Handicap', 'SMSReceived',
#        'NoShow', 'sch_weekday', 'app_weekday'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Gender', 'ScheduledDay', 'AppointmentDay', 'Age', 'Scholarship',
#        'Hypertension', 'Diabetes', 'Alcoholism', 'Handicap', 'SMSReceived',
#        'NoShow', 'sch_weekday', 'app_weekday'],
#       dtype='object')

# %% [markdown]
# ### check unique values for target variable

# %%
print(df["NoShow"].value_counts())
# Out:
# NoShow
# No     88208
# Yes    22319
# Name: count, dtype: int64

# %% [markdown]
# ### Insights
# - Most patients attended their appointments

# %% [markdown]
# ### Plot the count of 'NoSshow' occurrences

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="NoShow", palette="coolwarm")

# Add labels and title
plt.xlabel("No-show Status")
plt.ylabel("Count")
plt.title("Distribution of No-show Appointments")
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1768\1825977691.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="NoShow", palette="coolwarm")

# %% [markdown]
# ### calculating % of appointment or not

# %%
round(df["NoShow"].value_counts()*100/len(df["NoShow"]),2)
# Out:
# NoShow
# No     79.81
# Yes    20.19
# Name: count, dtype: float64

# %% [markdown]
# ###  checking duplicated values

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### checking null values

# %%
missing=pd.DataFrame({"count":df.isnull().sum(),
                      "percentage":df.isnull().mean()})
#display the table
print(missing)
# Out:
#                 count  percentage
# Gender              0         0.0
# ScheduledDay        0         0.0
# AppointmentDay      0         0.0
# Age                 0         0.0
# Scholarship         0         0.0
# Hypertension        0         0.0
# Diabetes            0         0.0
# Alcoholism          0         0.0
# Handicap            0         0.0
# SMSReceived         0         0.0
# NoShow              0         0.0
# sch_weekday         0         0.0
# app_weekday         0         0.0

# %% [markdown]
# ### Insights
# - Here, we do not have any missing data
#
# ### GENERAL RULES:
# - for features with less missing values :- fill with the mean of the values ,depending on  the features.
# - for features with very high number of missing values:- it is better to drop these columns ,if you have more than 30-40% of  missing data you can delete the columns

# %% [markdown]
# # Data cleaning

# %% [markdown]
# #### create a copy of df for manupulation and processing

# %%
new_data=df.copy()

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Gender          110527 non-null  object
#  1   ScheduledDay    110527 non-null  datetime64[ns]
#  2   AppointmentDay  110527 non-null  datetime64[ns]
#  3   Age             110527 non-null  int64
#  4   Scholarship     110527 non-null  int64
#  5   Hypertension    110527 non-null  int64
#  6   Diabetes        110527 non-null  int64
#  7   Alcoholism      110527 non-null  int64
#  8   Handicap        110527 non-null  int64
#  9   SMSReceived     110527 non-null  int64
#  10  NoShow          110527 non-null  object
#  11  sch_weekday     110527 non-null  int32
#  12  app_weekday     110527 non-null  int32
# dtypes: datetime64[ns](2), int32(2), int64(7), object(2)
# memory usage: 10.1+ MB

# %% [markdown]
# ### get the max tenure

# %%
print(df["Age"].max())
# Out:
# 115

# %% [markdown]
# ### This bar plot shows the top 20 most common ages in the dataset

# %%
# bar plot for age column
plt.figure(figsize=(14, 6))
sns.barplot(x=df['Age'].value_counts().index[:20],
    y=df['Age'].value_counts().values[:20],  # Top 20 age 
            palette="coolwarm")

plt.title("Age Distribution in the Dataset")
plt.xlabel("Age")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1768\1089976168.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Age'].value_counts().index[:20],

# %% [markdown]
# ### noshow rate by gender

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Gender", hue="NoShow", data=df, palette="coolwarm")
plt.title("No-show Rate by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(["Showed Up", "No-show"])
plt.show()

# %% [markdown]
# ### Insights
# ##### Gender:
#
# - More female patients than male patients in the dataset.
# - The no-show rate is similar for both genders, meaning gender is not a strong factor.

# %% [markdown]
# ###  Do patients with multiple medical conditions have lower no-show rates?

# %%
df['TotalConditions'] = df['Hypertension'] + df['Diabetes']+  df['Alcoholism'] + df['Handicap']

plt.figure(figsize=(10, 5))
sns.barplot(x=df['TotalConditions'], y=df['NoShow'], palette="coolwarm")
plt.title("No-show Rate by Number of Medical Conditions")
plt.xlabel("Number of Medical Conditions")
plt.ylabel("NoShow Rate")
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1768\529177423.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['TotalConditions'], y=df['NoShow'], palette="coolwarm")

# %% [markdown]
# ### Insights
# - patients with more medical issues attend more consistently.

# %% [markdown]
# ### Select only numeric columns for correlation matrix

# %%
correlation_matrix = df[numerical_columns].corr()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 correlation_matrix = df[numerical_columns].corr()
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...

# %%
correlation_matrix = df[numerical_columns].corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f",)
plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %% [markdown]
# ### Insights
# - Identifies strong relationships between variable

# %% [markdown]
# ### convert all the categorical variables into dummy variables

# %%
df_dummies=pd.get_dummies(df)
df_dummies.head()
# Out:
#   ScheduledDay AppointmentDay  Age  Scholarship  Hypertension  Diabetes  \
# 0   2016-04-29     2016-04-29   62            0             1         0
# 1   2016-04-29     2016-04-29   56            0             0         0
# 2   2016-04-29     2016-04-29   62            0             0         0
# 3   2016-04-29     2016-04-29    8            0             0         0
# 4   2016-04-29     2016-04-29   56            0             1         1
#
#    Alcoholism  Handicap  SMSReceived  sch_weekday  ...  Gender_F  Gender_M  \
# 0           0         0            0            4  ...      True     False
# 1           0         0            0            4  ...     False      True
# 2           0         0            0            4  ...      True     False
# 3           0         0            0            4  ...      True     False
# 4           0         0            0            4  ...      True     False
#
#    NoShow_No  NoShow_Yes  AgeGroup_0-18  AgeGroup_19-35  AgeGroup_36-50  \
# ...
